# %%
import matplotlib
import pandas as pd
import seaborn as sns
import math
import statistics
import numpy as np

sns.set(color_codes=True)
finalconsumption = pd.read_csv('Natural Gas (Including LNG).csv')
finalconsumption.info()
finalconsumption
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291 entries, 0 to 290
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  290 non-null    object
#  1   Commodity - Transaction  290 non-null    object
#  2   Year                     288 non-null    float64
#  3   Quantity-Terajoules      288 non-null    float64
#  4   Quantity Footnotes       59 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 11.5+ KB
#                      Country                          Commodity - Transaction  \
# 0                    Algeria  Natural gas (including LNG) - final consumption
# 1                    Algeria  Natural gas (including LNG) - final consumption
# 2                    Algeria  Natural gas (including LNG) - final consumption
# 3                    Algeria  Natural gas (including LNG) - final consumption
# ...

# %% [markdown]
# ##### The datasheet above displays the quantity of Natural gas (including LNG) - final consumption in a table of African Countries for years ranging from 1999 - 2019.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
finalConsumption = pd.read_csv('Natural Gas (Including LNG).csv')
 
plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*60+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
   

plt.legend(loc= "best")
sns.barplot(finalConsumption['Country'],finalConsumption['Quantity-Terajoules'], finalConsumption['Year'])
# Out:
# No handles with labels found to put in legend.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country', ylabel='Quantity-Terajoules'>

# %%
plt.figure(figsize=(12,10))

def interquartile_range(sample):
    q3, q1 = np.percentile(sample, [75 ,25])
    return q3 - q1

def quartile_range(sample):
    q3, q1 = np.percentile(sample, [75 ,25])
    return (q3 - q1)/2

def _range(sample):
    return sample.max() - sample.min()

def create_plot(fn, label):
    ls = []
    for year in range(1999,2018):
            ls.append(fn(finalConsumption[finalConsumption['Year'] == year]['Quantity-Terajoules']))
              
    plt.plot(range(1999,2018), ls, label=label)
    plt.title('Natural gas (including LNG) - final consumption')
    plt.ylabel('Quantity-Terajoules')
    plt.xlabel('Year')
    
create_plot(statistics.mean, 'Mean')
create_plot(statistics.variance, 'Variance')
create_plot(statistics.stdev, 'Standard Deviation')
create_plot(interquartile_range, 'Interquartile Range')
create_plot(quartile_range, 'Quartile Range')
create_plot(_range, 'Range')


plt.legend(loc='best')
